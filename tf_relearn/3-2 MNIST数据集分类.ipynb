# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
# 载入数据
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)
# Out:
# WARNING:tensorflow:From /Users/zhulf/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/zhulf/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# ...

# %%
# 每个批次的大小
# batch_size = 100
batch_size = 200
# 计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

# 定义两个placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])

# 创建一个简单的神经网络
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))

prediction = tf.nn.softmax(tf.matmul(x, W) + b)

# 二次代价函数
#loss = tf.reduce_mean(tf.square(y - prediction))

# 交叉熵代价函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = y, logits = prediction))

train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

# 结果存放在一个Bool型列表中
correct_predition = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))
# 求准确率
accuracy = tf.reduce_mean(tf.cast(correct_predition, tf.float32))


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(21):
        
        # w_val = sess.run(W)
        
        # print w_val[12, 8], w_val[12, 3], w_val[102, 8], w_val[11, 8]
        
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys})
        
        train_acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys})
        acc = sess.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels})
        
        print "iter: " + str(epoch) + ", train accuracy: " + str(train_acc)
        print "iter: " + str(epoch) + ", test accuracy: " + str(acc)
# Out:
# iter: 0, train accuracy: 0.79
# iter: 0, test accuracy: 0.8119
# iter: 1, train accuracy: 0.845
# iter: 1, test accuracy: 0.825
# iter: 2, train accuracy: 0.87
# iter: 2, test accuracy: 0.8804
# iter: 3, train accuracy: 0.905
# iter: 3, test accuracy: 0.8943
# iter: 4, train accuracy: 0.925
# iter: 4, test accuracy: 0.8976
# iter: 5, train accuracy: 0.92
# iter: 5, test accuracy: 0.9016
# iter: 6, train accuracy: 0.94
# iter: 6, test accuracy: 0.9042
# iter: 7, train accuracy: 0.935
# iter: 7, test accuracy: 0.9054
# iter: 8, train accuracy: 0.935
# iter: 8, test accuracy: 0.9067
# iter: 9, train accuracy: 0.93
# iter: 9, test accuracy: 0.9081
# iter: 10, train accuracy: 0.925
# iter: 10, test accuracy: 0.909
# iter: 11, train accuracy: 0.915
# iter: 11, test accuracy: 0.9099
# iter: 12, train accuracy: 0.885
# iter: 12, test accuracy: 0.9105
# iter: 13, train accuracy: 0.925
# iter: 13, test accuracy: 0.9117
# iter: 14, train accuracy: 0.88
# iter: 14, test accuracy: 0.9136
# ...

# %%
 # 二次代价函数
iter: 0, test accuracy: 0.744
iter: 1, test accuracy: 0.8314
iter: 2, test accuracy: 0.8591
iter: 3, test accuracy: 0.8703
iter: 4, test accuracy: 0.8775
iter: 5, test accuracy: 0.8814
iter: 6, test accuracy: 0.8846
iter: 7, test accuracy: 0.8876
iter: 8, test accuracy: 0.891
iter: 9, test accuracy: 0.8944
iter: 10, test accuracy: 0.8958
iter: 11, test accuracy: 0.8979
iter: 12, test accuracy: 0.8985
iter: 13, test accuracy: 0.8991
iter: 14, test accuracy: 0.9007
iter: 15, test accuracy: 0.9011
iter: 16, test accuracy: 0.9029
iter: 17, test accuracy: 0.9041
iter: 18, test accuracy: 0.9047
iter: 19, test accuracy: 0.9052
iter: 20, test accuracy: 0.9059
        
# 交叉熵代价函数
iter: 0, test accuracy: 0.8133
iter: 1, test accuracy: 0.8246
iter: 2, test accuracy: 0.8708
iter: 3, test accuracy: 0.8929
iter: 4, test accuracy: 0.8972
iter: 5, test accuracy: 0.9007
iter: 6, test accuracy: 0.9034
iter: 7, test accuracy: 0.9057
iter: 8, test accuracy: 0.9074
iter: 9, test accuracy: 0.9084
iter: 10, test accuracy: 0.91
iter: 11, test accuracy: 0.9097
iter: 12, test accuracy: 0.9114
iter: 13, test accuracy: 0.9118
iter: 14, test accuracy: 0.9132
iter: 15, test accuracy: 0.9135
iter: 16, test accuracy: 0.9135
iter: 17, test accuracy: 0.9144
iter: 18, test accuracy: 0.915
iter: 19, test accuracy: 0.9167
iter: 20, test accuracy: 0.9169
