# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xa
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xa

# %%
# 载入数据
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)


# 每个批次的大小
batch_size = 100
# batch_size = 200
# 计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

# 定义两个placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])
keep_prob = tf.placeholder(tf.float32)

# 优化 1
lr = tf.Variable(0.001, dtype=tf.float32)


# 优化2: 创建一个简单的神经网络
W1 = tf.Variable(tf.truncated_normal([784, 500], stddev=0.1))
b1 = tf.Variable(tf.zeros([500]) + 0.1)
L1 = tf.nn.tanh(tf.matmul(x, W1) + b1)
L1_drop = tf.nn.dropout(L1, keep_prob)

W2 = tf.Variable(tf.truncated_normal([500, 300], stddev=0.1))
b2 = tf.Variable(tf.zeros([300]) + 0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop, W2) + b2)
L2_drop = tf.nn.dropout(L2, keep_prob)

W3 = tf.Variable(tf.truncated_normal([300, 10], stddev=0.1))
b3 = tf.Variable(tf.zeros([10]) + 0.1)
prediction = tf.matmul(L2_drop, W3) + b3


# 二次代价函数
#loss = tf.reduce_mean(tf.square(y - prediction))

# 交叉熵代价函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = y, logits = prediction))

# train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)
train_step = tf.train.AdamOptimizer(lr).minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

# 结果存放在一个Bool型列表中
correct_predition = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))
# 求准确率
accuracy = tf.reduce_mean(tf.cast(correct_predition, tf.float32))


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(21):
        
        sess.run(tf.assign(lr, 0.001 * (0.95 ** epoch)))
        learning_rate = sess.run(lr)
        # w_val = sess.run(W)
        
        # print w_val[12, 8], w_val[12, 3], w_val[102, 8], w_val[11, 8]
        
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.0})
        
        train_acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.0})
        acc = sess.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels, keep_prob: 1.0})
        
        print "iter: " + str(epoch) + ", train accuracy: " + str(train_acc) + ", iter: " + str(epoch) + ", test accuracy: " + str(acc) + ', learning_rate: ' + str(learning_rate)
# Out:
# WARNING:tensorflow:From <ipython-input-2-246dbb8df0d9>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/zhulf/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/zhulf/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# ...

# %%
# lr = 0.001
iter: 0, train accuracy: 0.88
iter: 0, test accuracy: 0.9006
iter: 1, train accuracy: 0.87
iter: 1, test accuracy: 0.9126
iter: 2, train accuracy: 0.94
iter: 2, test accuracy: 0.917
iter: 3, train accuracy: 0.91
iter: 3, test accuracy: 0.9203
iter: 4, train accuracy: 0.89
iter: 4, test accuracy: 0.9202
iter: 5, train accuracy: 0.95
iter: 5, test accuracy: 0.9237
iter: 6, train accuracy: 0.94
iter: 6, test accuracy: 0.9254
iter: 7, train accuracy: 0.86
iter: 7, test accuracy: 0.9262
iter: 8, train accuracy: 0.92
iter: 8, test accuracy: 0.9277
iter: 9, train accuracy: 0.92
iter: 9, test accuracy: 0.9288
iter: 10, train accuracy: 0.96
iter: 10, test accuracy: 0.9292
iter: 11, train accuracy: 0.91
iter: 11, test accuracy: 0.9301
iter: 12, train accuracy: 0.94
iter: 12, test accuracy: 0.9306
iter: 13, train accuracy: 0.94
iter: 13, test accuracy: 0.9302
iter: 14, train accuracy: 0.91
iter: 14, test accuracy: 0.9295
iter: 15, train accuracy: 0.95
iter: 15, test accuracy: 0.9308
iter: 16, train accuracy: 0.95
iter: 16, test accuracy: 0.9303
iter: 17, train accuracy: 0.9
iter: 17, test accuracy: 0.9315
iter: 18, train accuracy: 0.99
iter: 18, test accuracy: 0.9301
iter: 19, train accuracy: 0.95
iter: 19, test accuracy: 0.9319
iter: 20, train accuracy: 0.92
iter: 20, test accuracy: 0.9315
# Out:
#   File "<ipython-input-3-72c877f10bbf>", line 2
#     iter: 0, train accuracy: 0.88
#         ^
# SyntaxError: invalid syntax
